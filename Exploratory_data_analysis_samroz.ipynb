# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
df=pd.read_csv("G:\/police.csv")
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %% [markdown]
# pip install seaborn

# %%
df.tail()
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type stop_outcome  \
# 91736          Speeding             False         NaN      Warning
# ...

# %%
len(df)
# Out:
# 91741

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %%
df[df.isnull().sum(axis=1).sort_values(ascending=False)>10]
# Out:
# C:\Users\Samroz\AppData\Local\Temp\ipykernel_12908\2635077609.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.isnull().sum(axis=1).sort_values(ascending=False)>10]
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 25     2005-09-03     16:02          NaN           NaN             NaN
# 29     2005-09-26     01:05          NaN           NaN             NaN
# 52     2005-10-01     13:09          NaN           NaN             NaN
# 110    2005-10-03     19:50          NaN           NaN             NaN
# 124    2005-10-04     11:43          NaN           NaN             NaN
# ...           ...       ...          ...           ...             ...
# 91637  2015-12-27     09:41          NaN           NaN             NaN
# 91660  2015-12-28     02:28          NaN           NaN             NaN
# 91674  2015-12-28     12:01          NaN           NaN             NaN
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
col=df.isnull().sum().sort_values(ascending=False).head(2).index.values

# %%
df=df.drop(col,axis="columns")

# %%
df.isnull().sum().sort_values(ascending=False)/len(df)*100
# Out:
# driver_age            6.127032
# driver_gender         5.815284
# driver_race           5.813104
# violation_raw         5.813104
# violation             5.813104
# stop_outcome          5.813104
# is_arrested           5.813104
# stop_duration         5.813104
# driver_age_raw        5.806564
# stop_date             0.000000
# stop_time             0.000000
# search_conducted      0.000000
# drugs_related_stop    0.000000
# dtype: float64

# %%
df["driver_age"].describe()
# Out:
# count    86120.000000
# mean        34.011333
# std         12.738564
# min         15.000000
# 25%         23.000000
# 50%         31.000000
# 75%         43.000000
# max         99.000000
# Name: driver_age, dtype: float64

# %%
df=df[df.isnull().sum(axis=1)<5]
df
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
df=df[df["driver_age"].notnull()]

# %%
df.isnull().sum().sort_values(ascending=False)/len(df)*100
# Out:
# driver_gender         0.002322
# stop_date             0.000000
# stop_time             0.000000
# driver_age_raw        0.000000
# driver_age            0.000000
# driver_race           0.000000
# violation_raw         0.000000
# violation             0.000000
# search_conducted      0.000000
# stop_outcome          0.000000
# is_arrested           0.000000
# stop_duration         0.000000
# drugs_related_stop    0.000000
# dtype: float64

# %%
df=df[df["driver_gender"].notnull()]

# %%
df=df.rename(columns={"driver_age_raw":"driver_DOB"})

# %%
df
# Out:
#         stop_date stop_time driver_gender  driver_DOB  driver_age driver_race  \
# 0      2005-01-02     01:55             M      1985.0        20.0       White
# 1      2005-01-18     08:15             M      1965.0        40.0       White
# 2      2005-01-23     23:15             M      1972.0        33.0       White
# 3      2005-02-20     17:15             M      1986.0        19.0       White
# 4      2005-03-14     10:00             F      1984.0        21.0       White
# ...           ...       ...           ...         ...         ...         ...
# 91736  2015-12-31     20:27             M      1986.0        29.0       White
# 91737  2015-12-31     20:35             F      1982.0        33.0       White
# 91738  2015-12-31     20:45             M      1992.0        23.0       White
# 91739  2015-12-31     21:42             M      1993.0        22.0       White
# 91740  2015-12-31     22:46             M      1959.0        56.0    Hispanic
#
# ...

# %%
#Exploratory dataanalysis

# %%
df["driver_gender"]
# Out:
# 0        M
# 1        M
# 2        M
# 3        M
# 4        F
#         ..
# 91736    M
# 91737    F
# 91738    M
# 91739    M
# 91740    M
# Name: driver_gender, Length: 86113, dtype: object

# %%
sns.countplot(x="driver_gender",data=df)
# Out:
# <Axes: xlabel='driver_gender', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(y="violation_raw",data=df,hue="driver_gender")
# Out:
# <Axes: xlabel='count', ylabel='violation_raw'>

# %%
sns.countplot(x="driver_race",data=df,hue="driver_gender")
# Out:
# <Axes: xlabel='driver_race', ylabel='count'>

# %%
sns.countplot(x="search_conducted",data=df,hue="driver_gender")
# Out:
# <Axes: xlabel='search_conducted', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="drugs_related_stop",data=df,hue="driver_gender")
# Out:
# <Axes: xlabel='drugs_related_stop', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="stop_duration",data=df,hue="driver_gender")
# Out:
# <Axes: xlabel='stop_duration', ylabel='count'>

# %%
#results of exploratory data analysis(EDA)
#In our clean data records most of them are MEN(60000+)
#most of the voilation are due to speed
#most of the people are white in our dataset and on 2nd number people are from black race
#on almost 83000 people police didnot conduct a research 
#drug related stop are very less
